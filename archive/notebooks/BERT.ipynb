# %%
# Install necessary libraries
# Rasa requires python 3.5-3.9 for bug issues with installation
# !pip install transformers datasets
# !pip install huggingface_hub
# !pip install rasa
# !pip install scikit-learn
# !pip install ipywidgets
# !pip install dotenv
# Out:
# Requirement already satisfied: transformers in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (4.55.3)
# Requirement already satisfied: datasets in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (4.0.0)
# Requirement already satisfied: filelock in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (20.9)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from datasets) (2.3.2)
# Requirement already satisfied: xxhash in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (4.0.3)
# Requirement already satisfied: idna>=2.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from packaging>=20.0->transformers) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# ^C
# Requirement already satisfied: scikit-learn in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (1.1.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from scikit-learn) (3.6.0)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 8.18.1 requires prompt-toolkit<3.1.0,>=3.0.41, but you have prompt-toolkit 3.0.28 which is incompatible.
# Requirement already satisfied: rasa in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (3.6.21)
# Requirement already satisfied: CacheControl<0.13.0,>=0.12.9 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.12.14)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (2.10.1)
# Requirement already satisfied: SQLAlchemy<1.5.0,>=1.4.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.4.54)
# Requirement already satisfied: absl-py<1.5,>=0.9 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.4.0)
# Requirement already satisfied: aio-pika<8.2.4,>=6.7.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (8.2.3)
# Requirement already satisfied: aiogram<2.26 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.15)
# Requirement already satisfied: aiohttp<3.10,>=3.9.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (3.9.5)
# Requirement already satisfied: apscheduler<3.10,>=3.6 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (3.9.1.post1)
# Requirement already satisfied: attrs<22.2,>=19.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (22.1.0)
# Requirement already satisfied: boto3<2.0.0,>=1.26.136 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.40.17)
# Requirement already satisfied: certifi>=2023.7.22 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2025.8.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.4 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.4.6)
# Requirement already satisfied: colorclass<2.3,>=2.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.2.2)
# Requirement already satisfied: coloredlogs<16,>=10 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (15.0.1)
# Requirement already satisfied: colorhash<1.3.0,>=1.0.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.2.1)
# Requirement already satisfied: confluent-kafka<3.0.0,>=1.9.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.11.1)
# Requirement already satisfied: cryptography>=41.0.7 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (45.0.6)
# Requirement already satisfied: dask==2022.10.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2022.10.2)
# Requirement already satisfied: dnspython==2.3.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.3.0)
# Requirement already satisfied: fbmessenger<6.1.0,>=6.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (6.0.0)
# Requirement already satisfied: google-auth<3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.40.3)
# Requirement already satisfied: jsonpickle<3.1,>=1.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (3.0.4)
# Requirement already satisfied: jsonschema<4.18,>=3.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (4.17.3)
# Requirement already satisfied: matplotlib<3.6,>=3.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (3.5.3)
# Requirement already satisfied: mattermostwrapper<2.3,>=2.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.2)
# Requirement already satisfied: networkx<2.7,>=2.4 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.6.3)
# Requirement already satisfied: numpy<1.25.0,>=1.19.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.23.5)
# Requirement already satisfied: packaging<21.0,>=20.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (20.9)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.6.0)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.10.1)
# Collecting prompt-toolkit<3.0.29,>=3.0 (from rasa)
#   Using cached prompt_toolkit-3.0.28-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: protobuf<4.23.4,>=4.23.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (4.23.3)
# Requirement already satisfied: psycopg2-binary<2.10.0,>=2.8.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.9.10)
# Requirement already satisfied: pydantic<1.10.10 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.10.9)
# Requirement already satisfied: pydot<1.5,>=1.4 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.4.2)
# Requirement already satisfied: pykwalify<1.9,>=1.7 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.8.0)
# Requirement already satisfied: pymongo<4.4,>=3.8 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from pymongo[srv,tls]<4.4,>=3.8->rasa) (4.3.3)
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.8.2)
# Requirement already satisfied: python-engineio!=5.0.0,<6,>=4 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (4.12.2)
# Requirement already satisfied: python-socketio<6,>=4.4 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (5.13.0)
# Requirement already satisfied: pytz<2023.0,>=2019.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2022.7.1)
# Requirement already satisfied: pyyaml>=6.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (6.0.2)
# Requirement already satisfied: questionary<1.11.0,>=1.5.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.10.0)
# Requirement already satisfied: randomname<0.2.0,>=0.1.5 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.1.5)
# Requirement already satisfied: rasa-sdk<3.7.0,>=3.6.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (3.6.2)
# Requirement already satisfied: redis<5.0,>=4.5.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (4.6.0)
# Requirement already satisfied: regex<2022.11,>=2020.6 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2022.10.31)
# Requirement already satisfied: requests<3.0,>=2.23 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.32.5)
# Requirement already satisfied: rocketchat_API<1.31.0,>=0.6.31 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.30.0)
# Requirement already satisfied: ruamel.yaml<0.17.22,>=0.16.5 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.17.21)
# Requirement already satisfied: safetensors<0.5.0,>=0.4.5 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.4.5)
# Requirement already satisfied: sanic<21.13,>=21.12 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (21.12.2)
# Requirement already satisfied: sanic-cors<2.1.0,>=2.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.0.1)
# Requirement already satisfied: sanic-jwt<2.0.0,>=1.6.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.8.0)
# Requirement already satisfied: sanic-routing<0.8.0,>=0.7.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.7.2)
# Requirement already satisfied: scikit-learn<1.2,>=0.22 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.1.3)
# Requirement already satisfied: scipy<1.11.0,>=1.10.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.10.1)
# Requirement already satisfied: sentry-sdk<1.15.0,>=0.17.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.14.0)
# Requirement already satisfied: setuptools<70.4.0,>=70.3.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (70.3.0)
# Requirement already satisfied: sklearn-crfsuite<0.4,>=0.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.3.6)
# Requirement already satisfied: skops==0.9.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.9.0)
# Requirement already satisfied: slack-sdk<4.0.0,>=3.19.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (3.36.0)
# Requirement already satisfied: structlog<24.0.0,>=23.1.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (23.3.0)
# Requirement already satisfied: structlog-sentry<3.0.0,>=2.0.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.1.0)
# Requirement already satisfied: tarsafe<0.0.5,>=0.0.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.0.4)
# Requirement already satisfied: tensorflow==2.12.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.31 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.31.0)
# Requirement already satisfied: tensorflow_hub<0.14.0,>=0.13.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.13.0)
# Requirement already satisfied: terminaltables<3.2.0,>=3.1.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (3.1.10)
# Requirement already satisfied: tqdm<5.0,>=4.31 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (4.67.1)
# Requirement already satisfied: twilio<8.3,>=6.26 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (8.2.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (4.14.1)
# Requirement already satisfied: typing-utils<0.2.0,>=0.1.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.1.0)
# Requirement already satisfied: ujson<6.0,>=1.35 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (5.11.0)
# Requirement already satisfied: webexteamssdk<1.7.0,>=1.1.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (1.6.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (10.4)
# Requirement already satisfied: wheel>=0.38.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rasa) (0.45.1)
# Requirement already satisfied: click>=7.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from dask==2022.10.2->rasa) (8.1.8)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from dask==2022.10.2->rasa) (3.1.1)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from dask==2022.10.2->rasa) (2025.3.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from dask==2022.10.2->rasa) (1.4.2)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from dask==2022.10.2->rasa) (1.0.0)
# Requirement already satisfied: huggingface-hub>=0.17.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from skops==0.9.0->rasa) (0.34.4)
# Requirement already satisfied: tabulate>=0.8.8 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from skops==0.9.0->rasa) (0.9.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (0.4.30)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (3.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (3.1.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (1.14.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (1.74.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorflow-intel==2.12.0->rasa) (2.12.0)
# Requirement already satisfied: aiormq~=6.4.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aio-pika<8.2.4,>=6.7.1->rasa) (6.4.2)
# Requirement already satisfied: yarl in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aio-pika<8.2.4,>=6.7.1->rasa) (1.20.1)
# Requirement already satisfied: Babel>=2.8.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiogram<2.26->rasa) (2.17.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp<3.10,>=3.9.0->rasa) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp<3.10,>=3.9.0->rasa) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp<3.10,>=3.9.0->rasa) (5.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiohttp<3.10,>=3.9.0->rasa) (4.0.3)
# Requirement already satisfied: pamqp==3.2.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from aiormq~=6.4.0->aio-pika<8.2.4,>=6.7.1->rasa) (3.2.1)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from apscheduler<3.10,>=3.6->rasa) (5.3.1)
# Requirement already satisfied: botocore<1.41.0,>=1.40.17 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from boto3<2.0.0,>=1.26.136->rasa) (1.40.17)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from boto3<2.0.0,>=1.26.136->rasa) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from boto3<2.0.0,>=1.26.136->rasa) (0.13.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from botocore<1.41.0,>=1.40.17->boto3<2.0.0,>=1.26.136->rasa) (1.26.20)
# Requirement already satisfied: msgpack>=0.5.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from CacheControl<0.13.0,>=0.12.9->rasa) (1.1.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from coloredlogs<16,>=10->rasa) (10.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from google-auth<3->rasa) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from google-auth<3->rasa) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from google-auth<3->rasa) (4.9.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from jsonschema<4.18,>=3.2->rasa) (0.20.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (11.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (3.2.3)
# Requirement already satisfied: pywin32>=226 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from portalocker<3.0.0,>=2.7.0->rasa) (311)
# Requirement already satisfied: wcwidth in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from prompt-toolkit<3.0.29,>=3.0->rasa) (0.2.13)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from pykwalify<1.9,>=1.7->rasa) (0.6.2)
# Requirement already satisfied: simple-websocket>=0.10.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from python-engineio!=5.0.0,<6,>=4->rasa) (1.1.0)
# Requirement already satisfied: bidict>=0.21.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from python-socketio<6,>=4.4->rasa) (0.23.1)
# Requirement already satisfied: fire in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from randomname<0.2.0,>=0.1.5->rasa) (0.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from requests<3.0,>=2.23->rasa) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from requests<3.0,>=2.23->rasa) (3.10)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3->rasa) (0.6.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ruamel.yaml<0.17.22,>=0.16.5->rasa) (0.2.12)
# Requirement already satisfied: httptools>=0.0.10 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from sanic<21.13,>=21.12->rasa) (0.6.4)
# Requirement already satisfied: aiofiles>=0.6.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from sanic<21.13,>=21.12->rasa) (24.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from scikit-learn<1.2,>=0.22->rasa) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from scikit-learn<1.2,>=0.22->rasa) (3.6.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from sklearn-crfsuite<0.4,>=0.3->rasa) (0.9.11)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from SQLAlchemy<1.5.0,>=1.4.0->rasa) (3.2.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->rasa) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->rasa) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->rasa) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->rasa) (3.1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->rasa) (2.0.0)
# Requirement already satisfied: aiohttp-retry>=2.8.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from twilio<8.3,>=6.26->rasa) (2.9.1)
# Requirement already satisfied: future in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa) (1.0.0)
# Requirement already satisfied: requests-toolbelt in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa) (1.0.0)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from yarl->aio-pika<8.2.4,>=6.7.1->rasa) (0.3.2)
# Requirement already satisfied: cffi>=1.14 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from cryptography>=41.0.7->rasa) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from cffi>=1.14->cryptography>=41.0.7->rasa) (2.22)
# Requirement already satisfied: filelock in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from huggingface-hub>=0.17.0->skops==0.9.0->rasa) (3.19.1)
# Requirement already satisfied: pyreadline3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from humanfriendly>=9.1->coloredlogs<16,>=10->rasa) (3.5.4)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->rasa) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->rasa) (0.5.3)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->rasa) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from importlib-metadata>=4.6->jax>=0.3.15->tensorflow-intel==2.12.0->rasa) (3.23.0)
# Requirement already satisfied: locket in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from partd>=0.3.10->dask==2022.10.2->rasa) (1.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->rasa) (3.3.1)
# Requirement already satisfied: wsproto in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from simple-websocket>=0.10.0->python-engineio!=5.0.0,<6,>=4->rasa) (1.2.0)
# Requirement already satisfied: tzdata in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from tzlocal!=3.*,>=2.0->apscheduler<3.10,>=3.6->rasa) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->rasa) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio!=5.0.0,<6,>=4->rasa) (0.16.0)
# Using cached prompt_toolkit-3.0.28-py3-none-any.whl (380 kB)
# Installing collected packages: prompt-toolkit
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt_toolkit 3.0.51
#     Uninstalling prompt_toolkit-3.0.51:
#       Successfully uninstalled prompt_toolkit-3.0.51
# Successfully installed prompt-toolkit-3.0.28
# Requirement already satisfied: ipywidgets in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython>=6.1.0->ipywidgets)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack-data in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.14.1)
# Requirement already satisfied: exceptiongroup in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.3.0)
# Requirement already satisfied: colorama in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Installing collected packages: prompt-toolkit
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.28
#     Uninstalling prompt-toolkit-3.0.28:
#       Successfully uninstalled prompt-toolkit-3.0.28
# Successfully installed prompt-toolkit-3.0.52
# WARNING: Ignoring invalid distribution -rompt-toolkit (c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages)
# WARNING: Ignoring invalid distribution -rompt-toolkit (c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rompt-toolkit (c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasa 3.6.21 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.52 which is incompatible.
# rasa-sdk 3.6.2 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.52 which is incompatible.
# Requirement already satisfied: dotenv in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in c:\users\azizk\miniconda3\envs\ocelotbot\lib\site-packages (from dotenv) (1.1.1)

# %%
from datasets import load_dataset, load_from_disk
import os
from dotenv import load_dotenv

# %%
def preprocess_human_convo():
    # Preprocess the human conversation dataset
    f = open('human_convo.csv', 'x')
    dataset_path = os.path.join(os.getcwd().replace('notebooks', 'datasets\\'))
    human_convo_path = os.path.join(dataset_path, 'human_chat.csv')
    print(f"Loading dataset from: {human_convo_path}")

    with open(human_convo_path, 'r') as file:
        for line in file:
            f.write(line[:-2] + '\n')

    f.close()

preprocess_human_convo()

# %%
# Step 1: Load and preprocess the dataset from Hugging Face and Kaggle
# Authenticate HuggingFace
from huggingface_hub import login

load_dotenv(os.getcwd().replace('notebooks', ''))
HUGGINGFACE_TOKEN = os.getenv("HUGGINGFACE_TOKEN")
login(token=HUGGINGFACE_TOKEN)

# Load core datasets
dataset_path = os.path.join(os.getcwd().replace('notebooks', 'jsonl-datasets\\'))
print(f"Loading dataset from: {dataset_path}")

human_conversation = load_dataset(dataset_path, data_files=dataset_path + "human_convo.jsonl", split='train')
print(human_conversation)

mental_health = load_dataset(dataset_path, data_files='amod_health.jsonl', split='train')
print(mental_health)

# Load supplementary dataset for general conversations (Chatbot Arena Conversations)
chatbot_arena = load_dataset('lmsys/chatbot_arena_conversations', split='train')

# Keep only relevant columns
columns_to_keep = ['model_a', 'model_b', 'winner', 'conversation_a', 'conversation_b', "openai_moderation"]
chatbot_arena = chatbot_arena.remove_columns([col for col in chatbot_arena.column_names if col not in columns_to_keep])
print(chatbot_arena)

# Optional: Sample only a portion of the supplementary dataset to avoid overpowering the well-being focus
chatbot_arena = chatbot_arena.shuffle(seed=42).select(range(1000))  # Taking a random sample of 1000 examples

# Combine core and supplementary datasets (make sure core datasets are prioritized)
# combined_dataset = human_conversation.concatenate(mental_health).concatenate(chatbot_arena)

# combined_dataset[:10]  # Display first 10 entries to verify
# Out:
# Loading dataset from: c:\Users\azizk\Documents\GitHub\OcelotBot\jsonl-datasets\
# Dataset({
#     features: ['messages', 'domain', 'style', 'source'],
#     num_rows: 93
# })
# Dataset({
#     features: ['messages', 'domain', 'style', 'source', 'safety'],
#     num_rows: 3508
# })
# Dataset({
#     features: ['model_a', 'model_b', 'winner', 'conversation_a', 'conversation_b', 'openai_moderation'],
#     num_rows: 33000
# })

# %%
# Step 2: Fine-tune GPT-2 on the combined dataset
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments

# Load GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Preprocess the dataset for GPT-2
def preprocess_function(examples):
    return tokenizer(examples['text'], truncation=True, padding='max_length', max_length=128)

# Tokenize the combined dataset
tokenized_dataset = combined_dataset.map(preprocess_function, batched=True)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./gpt2-finetuned", 
    per_device_train_batch_size=8,
    num_train_epochs=3, 
    logging_dir="./logs",
    logging_steps=10
)

# Trainer for GPT-2
trainer = Trainer(
    model=model, 
    args=training_args, 
    train_dataset=tokenized_dataset
)

# Fine-tune the model
trainer.train()

# %%
# Step 3: Sentiment Analysis with BERT
from transformers import BertTokenizer, BertForSequenceClassification
import torch

# Load pre-trained BERT model for sentiment analysis
sentiment_tokenizer = BertTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')
sentiment_model = BertForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

# Function to classify sentiment using BERT
def sentiment_analysis_bert(text):
    inputs = sentiment_tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512)
    outputs = sentiment_model(**inputs)
    probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
    sentiment_class = torch.argmax(probs).item()
    sentiment_labels = ["Very Negative", "Negative", "Neutral", "Positive", "Very Positive"]
    return sentiment_labels[sentiment_class]

# Example sentiment analysis using BERT
text = "I'm feeling great today!"
print(f"BERT Sentiment: {sentiment_analysis_bert(text)}")

# %%
# Step 4: Fine-tune BERT on Mental Health Dataset (optional)
from transformers import Trainer, TrainingArguments

# Select a small subset of mental health dataset for fine-tuning BERT
subset_mental_health = mental_health.shuffle(seed=42).select(range(1000))

# Preprocess mental health counseling dataset for BERT
def preprocess_bert(examples):
    return sentiment_tokenizer(examples['text'], truncation=True, padding='max_length', max_length=128)

# Tokenize the dataset
tokenized_mental_health = subset_mental_health.map(preprocess_bert, batched=True)

# Fine-tune BERT on the selected mental health dataset
training_args_bert = TrainingArguments(
    output_dir="./bert-finetuned",
    per_device_train_batch_size=8,
    num_train_epochs=3,
    logging_dir="./bert_logs",
    logging_steps=10
)

bert_trainer = Trainer(
    model=sentiment_model,
    args=training_args_bert,
    train_dataset=tokenized_mental_health
)

# Fine-tune the BERT sentiment model
bert_trainer.train()

# %%
# Step 5: Setup Rasa for Multi-Turn Conversations
# Initialize a new Rasa project (do this once in terminal or Colab shell)
# !rasa init --no-prompt

# %%
# Add GPT-2 based response generator into Rasa's actions.py file (custom action)
from rasa_sdk import Action, Tracker
from rasa_sdk.executor import CollectingDispatcher
from typing import List, Dict
from transformers import GPT2LMHeadModel, GPT2Tokenizer

class ActionGenerateResponse(Action):
    def name(self) -> str:
        return "action_generate_response"

    def run(self, dispatcher: CollectingDispatcher,
            tracker: Tracker,
            domain: Dict) -> List[Dict]:

        # Load pre-trained GPT-2
        tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
        model = GPT2LMHeadModel.from_pretrained("./gpt2-finetuned")

        # Get the latest user message
        user_message = tracker.latest_message.get('text')

        # Tokenize and generate response using GPT-2
        inputs = tokenizer.encode(user_message, return_tensors='pt')
        outputs = model.generate(inputs, max_length=100, num_return_sequences=1)

        # Decode the response and send to user
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        dispatcher.utter_message(text=response)

        return []

# %%
# Step 6: Evaluation of the model using Scikit-learn
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Example true and predicted labels (replace with actual values)
y_true = [1, 0, 1, 1, 0]
y_pred = [1, 0, 0, 1, 1]

# Calculate evaluation metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
roc_auc = roc_auc_score(y_true, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"ROC-AUC: {roc_auc}")
